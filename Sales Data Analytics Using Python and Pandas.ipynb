# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv(r"C:\Users\johnm\OneDrive\Desktop\Fita Academy\sales_python.csv")

# Add total sales column
df['Total_Sales'] = df['Quantity'] * df['Price']

# Show top 5 records
print("Sample Data:")
print(df.head())

# Total sales by region
region_sales = df.groupby('Region')['Total_Sales'].sum()
print("\nSales by Region:")
print(region_sales)

# Total sales by product
product_sales = df.groupby('Product')['Total_Sales'].sum()
print("\nSales by Product:")
print(product_sales)

# Monthly trend
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
monthly_sales = df.groupby('Month')['Total_Sales'].sum()

# Plot 1: Sales by Region
region_sales.plot(kind='bar', title='Total Sales by Region', color='skyblue')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.tight_layout()
plt.show()

# Plot 2: Sales by Product
product_sales.plot(kind='bar', title='Total Sales by Product', color='salmon')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.tight_layout()
plt.show()

# Plot 3: Monthly Sales Trend
monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend', color='green')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(range(1, 13))
plt.tight_layout()
plt.show()
# Out:
# Sample Data:
#          Date Region   Product  Quantity  Price  Total_Sales
# 0  2024-01-05  South       Pen       120      5          600
# 1  2024-01-06  North  Notebook        60     15          900
# 2  2024-01-07   West    Pencil       150      3          450
# 3  2024-01-08   East       Pen       130      5          650
# 4  2024-01-09  South    Eraser       100      2          200
#
# Sales by Region:
# Region
# East     11612
# North    10808
# South    11367
# West      9353
# Name: Total_Sales, dtype: int64
#
# Sales by Product:
# Product
# Eraser       2644
# Notebook    21690
# Pen          9680
# Pencil       9126
# Name: Total_Sales, dtype: int64
